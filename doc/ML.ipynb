# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item"><li><span><a href="#Validation-Set" data-toc-modified-id="Validation-Set-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Validation Set</a></span></li><li><span><a href="#Kaggle-Competitions" data-toc-modified-id="Kaggle-Competitions-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Kaggle Competitions</a></span><ul class="toc-item"><li><span><a href="#Download" data-toc-modified-id="Download-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Download</a></span></li></ul></li><li><span><a href="#What-is-a-random-forest?" data-toc-modified-id="What-is-a-random-forest?-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>What is a random forest?</a></span><ul class="toc-item"><li><span><a href="#Why-Random-Forest-works-so-well" data-toc-modified-id="Why-Random-Forest-works-so-well-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Why Random Forest works so well</a></span></li><li><span><a href="#Limitations" data-toc-modified-id="Limitations-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Limitations</a></span></li></ul></li><li><span><a href="#Bagging-[47:12]" data-toc-modified-id="Bagging-[47:12]-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Bagging [47:12]</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Q:-The-subset-you-are-selecting,-are-they-exclusive?-Can-there-be-overlaps?-" data-toc-modified-id="Q:-The-subset-you-are-selecting,-are-they-exclusive?-Can-there-be-overlaps?--4.0.1"><span class="toc-item-num">4.0.1&nbsp;&nbsp;</span>Q: The subset you are selecting, are they exclusive? Can there be overlaps? <br></a></span></li><li><span><a href="#Q:-Wouldn’t-oobscore-always-lower-than-the-one-for-the-entire-forest" data-toc-modified-id="Q:-Wouldn’t-oobscore-always-lower-than-the-one-for-the-entire-forest-4.0.2"><span class="toc-item-num">4.0.2&nbsp;&nbsp;</span>Q: Wouldn’t oob<em>score</em> always lower than the one for the entire forest</a></span></li></ul></li><li><span><a href="#Grid-Search" data-toc-modified-id="Grid-Search-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Grid Search</a></span></li></ul></li><li><span><a href="#Out-of-Bag-(OOB)" data-toc-modified-id="Out-of-Bag-(OOB)-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Out of Bag (OOB)</a></span></li><li><span><a href="#Coefficient-of-Determination-$R^2$" data-toc-modified-id="Coefficient-of-Determination-$R^2$-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Coefficient of Determination $R^2$</a></span></li><li><span><a href="#Data-Leakage-and-Colinearity" data-toc-modified-id="Data-Leakage-and-Colinearity-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Data Leakage and Colinearity</a></span><ul class="toc-item"><li><span><a href="#Data-Leakage" data-toc-modified-id="Data-Leakage-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Data Leakage</a></span></li><li><span><a href="#Colinearity" data-toc-modified-id="Colinearity-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Colinearity</a></span></li><li><span><a href="#Throw-away-data" data-toc-modified-id="Throw-away-data-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Throw away data</a></span></li></ul></li><li><span><a href="#Feature-Importance" data-toc-modified-id="Feature-Importance-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Feature Importance</a></span></li><li><span><a href="#Calibration-of-Validation-set" data-toc-modified-id="Calibration-of-Validation-set-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Calibration of Validation set</a></span></li><li><span><a href="#position-of-random-forests" data-toc-modified-id="position-of-random-forests-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>position of random forests</a></span></li><li><span><a href="#size-of-validation-set" data-toc-modified-id="size-of-validation-set-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>size of validation set</a></span><ul class="toc-item"><li><span><a href="#Unbalanced-datasets" data-toc-modified-id="Unbalanced-datasets-11.1"><span class="toc-item-num">11.1&nbsp;&nbsp;</span>Unbalanced datasets</a></span></li></ul></li><li><span><a href="#Random-Forest-vs-ANN" data-toc-modified-id="Random-Forest-vs-ANN-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Random Forest vs ANN</a></span></li></ul></div>

# %% [markdown]
# # Validation Set
# Possibly the **most important idea** in ML is having separate training & validation data sets.
# **using all our data can lead to **overfitting**.
# A validation set helps diagnose this problem.
# A validation set is a 2nd (testing) set to be used at the end to check against overfitting.
# Don't look at it until the last moment ("Give it to someone else").

# %% [markdown]
# # Kaggle Competitions
#
# ML1 [12:05]
# Entering a Kaggle competition allows to know our competece at a kind of data / model.
# Is the accuracy bad because of noisy data so we cannot do better?
# Or have we made a mistake?
# When working on our own project and datasets, we will not get this kind of feedback.
# We just will have to know that we have good effective techniques to reliably building baseline model.<br>
#
# Kaggle is a good resource to improve ML skills, get hands-on practice and receiving real-time feedback.
# Kaggle provides:
# - Interesting data sets
# - Feedback on how you're doing
# - A leader board to see what's good, what's possible, and what's state-of-art.
# - Blog posts by winning contestants share useful tips and techniques.
#
# Machine learning should help us understand a dataset, not just make predictions about it [15:36].
# Picking an unfamiliar area is a good test of whether we can build an understanding.
# Otherwise our "intuition" about the data can make it difficult to be open-minded
# enough to see what the data really says.
#
# ## Download
# There are a few options to download the data:
# - Download to your computer and scp to AWS
# From Firefox [17:32], press ctrl + shift + i to open web developer tool.
# Go to Network tab, click on Download button, and cancel out of the dialog box.
# It shows network connections that were initiated.
# You then right-click on it and select Copy as cURL.
# Paste the command and add -o bulldozer.zip at the end (possibly remove — — 2.0 in the cURL command)

# %% [markdown]
# # What is a random forest?
# [36:37]
# Random forest is a universal machine learning technique.
# - It can predict something that can be of any kind —
#     - it could be a category (classification),
#     - a continuous variable (regression).
# - It can predict with columns of any kind — pixels, zip codes, revenues, etc. (i.e. both structured and unstructured data).
# - It does not generally overfit too badly, and it is very easy to stop it from overfitting.
# - In general, it does not need a separate validation set.
# - It can tell how well it generalizes even if we only have one dataset.
# - It has few, if any, statistical assumptions: It does not assume that the data is normally distributed, the relationship is linear, or specified interactions.
# - It requires very few pieces of feature engineering.
# - For many situations, we do not have to take the log of the data or multiply interactions together.
#
# ## Why Random Forest works so well
# ML1 [1:30:21]
#
# Take a look at one of the split point in the small single tree.
# Why does this even work?
# Imagine the only thing that mattered was Hydraulic Excavator, Track − 0.0 to 2.0 Metric Tons and nothing else mattered.
# It can pick out a single element by first splitting fiProductClassDesc ≤ 5.5 then fiProductClassDesc > 4.5 .
# With just two splits, we can pull out a single category.
# Tree is infinitely flexible even with a categorical variable.
# If there is a particular category which has different level of price, it can gradually zoom in on those group by using multiple splits.
# Random forest is very easy to use and very resilient.
#
#
# ## Limitations
# Random forest has no ability to do anything other than create binary splits on things like day of week, store number, item number.
# It does not know type of items or location of stores.
# Since its ability to understand what is going on is limited, we probably need to use the entire 4 years of data to even get some useful insights. But as soon as we start using the whole 4 years of data, a lot of the data we are using is really old. There is a Kaggle kernel that points out that what you could do is [35:54]:
#
# Take the last two weeks.
# Take the average sales by store number, by item number, by on promotion, then take a mean across date.
# Just submit that, and you come about 30th 🎉

# %% [markdown]
# # Bagging [47:12]
#
# [A Scalable Bootstrap for Massive Data](https://arxiv.org/abs/1112.5016?context=stat) by Michael Jordan et al.
# developed a technique called the Bag of Little Bootstraps (BLB).
# It shows how to use bagging for making any kind of model more robust and also to give you confidence intervals.
#
# Random forest — a way of bagging trees.
#
# So what is bagging?
# Bagging is having $n$ different models each of which was only somewhat predictive,
# but the models gave predictions that were not correlated with each other.
# The $n$ models would have profound different insights into the relationships in the data.
# If we take the average of those $n$ models, we are effectively bringing in the insights from each of them.
# Averaging models is a technique for Ensembling.
#
# Lets create many big, deep, massively overfit trees.
# But for each one, we only pick a random 1/10 of the data.
# Let’s do that a hundred times (different random sample every time).
# They are overfitting terribly, but since they are all using different random samples,
# they all overfit in different ways on different things.
# They all have errors but the errors are random.
# The average of a bunch of random errors is zero.
# If we take the average of these trees each of which have been trained on a different random subset,
# the error will average out to zero and what is left is the true relationship — and that’s the random forest.
#
# We average $n$ crappy models and we get a good model.
# [51:25]
# Because the crappy models are based on different random subsets and their errors are not correlated with each other. If the errors were correlated, this will not work.
#
# The key insight here is to construct multiple models which are better than nothing and where the errors are, as much as possible, not correlated with each other.
# The number of trees to use is the first of our hyper parameters we are going to tune to achieve higher metric.
#
# ### Q: The subset you are selecting, are they exclusive? Can there be overlaps? <br>
# ML1 [52:27]
# We talked about picking 1/10 at random, but what scikit-learn does by default is for n rows, it picks out n rows with replacement — which is called bootstrapping.
# If memory serves correctly, on average, 63.2% of the rows will be represented and many of them will be appear multiple times.
#
# The goal of modeling in ML is to find which variables are important and how do they interact together to drive your dependent variable.
# In practice, the difference between using the RF space to find your nearest neighbors vs. Euclidean space is the difference between a model that makes good predictions and the model that makes meaningless predictions.
#
# The effective ML model is accurate at finding the relationships in the training data and generalizes well to new data [55:53].
# In bagging, that means that each of your individual estimators, you want them to be as predictive as possible but for the predictions of your individual trees to be as uncorrelated as possible.
#
# **NB: It is more important to create uncorrelated trees than more accurate trees.**
# In scikit-learn, there is another class called `ExtraTreeClassifier` which is an extremely randomized tree model.
# Rather than trying every split of every variable, it randomly tries a few splits of a few variables which makes training much faster and it can build more trees — better generalization.
# If we have crappy individual models, you just need more trees to get a good end model.
#
# ### Q: Wouldn’t oob_score_ always lower than the one for the entire forest
# [1:12:51]?
# The accuracy tends to be lower because each row appears in less trees in the OOB samples than it does in the full set of trees.
# So OOB R² will slightly underestimate how generalizable the model is.
# But the more trees we add, the less serious that underestimation is.
#
# ## Grid Search
# OOB score will come in handy when setting hyper parameters [1:13:47].
# There will be quite a few hyper parameters that we are going to set and we would like to find some automated say to set them.
# One way to do that is to do grid search.
# Scikit-learn has a function called grid search and we pass in a list of all the hyper parameters to tune and all of the values of these hyper parameters we want to try.
# It will run the model on every possible combination of all these hyper parameters and tell you which one is the best. OOB score is a great choice for getting it to tell you which one is the best.

# %% [markdown]
# # Out of Bag (OOB)
#
# Is our validation set worse than our training set because we're over-fitting, or because the validation set is for a different time period, or a bit of both? With the existing information we've shown, we can't tell. However, RFs have a very clever trick called out-of-bag (OOB) error which can handle this (and more!)
#
# The idea is to calculate error on the training set, but only include the trees in the calculation of a row's error where that row was not included in training that tree.
# This allows us to see whether the model is over-fitting, without needing a separate validation set.
# It shows whether the model generalizes, even if we only have a small amount of data (and so want to avoid separating some for a validation set).
#
# This is done by adding oob_score=True to the model constructor. We print the OOB error last in our print_score function below.

# %% [markdown]
# # Coefficient of Determination $R^2$
# [Coefficient of Determination](https://en.wikipedia.org/wiki/Coefficient_of_determination) defines  $R^2$ "R squared": as the proportion of the variance in the dependent variable that is predictable from the independent variable(s). Important cases where the computational definition of $R^2$ can yield negative values, depending on the definition used, arise where:
# - the predictions that are being compared to the corresponding outcomes have not been derived from a model-fitting procedure using those data, and
# - where linear regression is conducted without including an intercept.
#
# Additionally, negative values of $R^2$ may occur when fitting non-linear functions to data.[6]
# When $R^2 < 0$, the mean of the data is a better fit to the outcomes.
#
# $R^2$ gives some information about the goodness of fit of a model.
# In regression, $R^2$ measures how well the regression line approximates the real data points.
# An $R^2 = 1$ indicates that the regression line perfectly fits the data.
#
# What is the possible range of $R^2$?
# [14:43]?
# Correct answer: Anything equal to or less than 1. If you predicted infinity for every row, R² = 1 −∞ <br>
# When $R^2$ is negative, the model is worse than predicting the mean.<br>
# $R^2$ is not what we are trying to optimize, but it is a number we can use for every model,
# to get a feel of what .8 or what .9 looks like.
#
# TODO: create synthetic 2D datasets with different amounts of random noise, and see what they look like on a scatterplot and their $R^2$ to get a feel of how close they are to the actual value.
#
# $R^2$ is the ratio between how good the model is (RMSE) vs. how good is the naïve mean model (RMSE).

# %% [markdown]
# # Data Leakage and Colinearity
#
# ## Data Leakage
# Example:
# [1:11:16]. A Kaggle competition goal was to predict which applications for grants at a university would be successful.
# A number of columns were almost entirely predictive of the dependent variable.
# Whether they were missing or not was the only thing that mattered.
# There was an administrative burden to fill details, so for many grant applications,
# they do not fill in the details for the folks whose applications were not accepted.
# Missing values in the dataset were identifying that the application wasn’t accepted.
# **Data leakage** means there is information in the dataset
# which they would not have had when they were making a decision.
# When the university was deciding which grant applications to accept,
# they do not know which ones the admin staff will later add details because it was accepted.
# Data leakage problems are serious and we need to deal with them.
#
# ## Colinearity
# [1:12:56].
# Another thing that will often find is signs of collinearity.
# (It seems like what happened with Coupler_System.)
# Coupler_System tells whether or not a particular kind of heavy industrial equipment has a particular feature on it. But if it is not that kind of industrial equipment at all, it will be missing.
# So it indicates whether or not it is a certain class of heavy industrial equipment.
# This is **not** data leakage, it is actual information we have at the right time.
# We have to be careful interpreting it.
# We should go through at least the top 10 (or look for where the natural break points are),
# and study these things carefully.
#
# ## Throw away data
# It is sometimes good to throw some data away and see if it make any difference.
# In the example, we had a RF with $R^2= .889$.
# We filtered out those where the importance is equal to or less than 0.005 (i.e. only keep the one whose importance is greater than 0.005).
#
# # Feature Importance
# [1:17:21]
# It is a simple technique that can be used not just for RF, but for basically any kind of ML model.
# Interestingly, few knows this.
# Many will say there is no way of interpreting this particular kind of model (knowing which things are important).
# But this technique actually works for (any?) kind of models.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# We take our data set and we have a column `Price` we are trying to predict (dependent variable).
# We have 25 independent variables, and one of them is `YearMade`.
# How do we figure out how important each variable, eg. `YearMade` is?
# We have a whole RF and we can find out our predictive accuracy.
# So we will put all these rows through our RF, and spit out some predictions.
# We then compare them to the actual price (e.g., root mean squared error and $R^2$).
# This is the starting point.<br>
# Let’s do the same thing again, but this time, we take the `YearMade` column and randomly shuffle it
# (i.e. randomly permute just that column).
# Now YearMade has exactly the same distribution as before (same mean, same standard deviation).
# But it has no relationships with the dependent variable (Price) at all because we randomly reordered it.
# Before, we might have found, e.g., that $R^2 = .89$.
# After we shuffled `YearMade`, $R^2 = .80$.
# So, $R^2$ got much worse when we destroyed that variable.
# Then we try again.
# We restore `YearMade` back to how it was originaly,
# and this time we take another column, e.g. `Enclosure` and shuffle it.
# Now $R^2 = .84$.
# So the amount of decrease for YearMade was $.09$ and for Enclosure it was $.05$.
# This give us our feature importances for each column.

# %% [markdown]
# Q: Can’t we just exclude the column and check the decay in performance [1:20:31]?
# You could remove the column and train a whole new RF, but that is going to be slow.
# This way, we keep the RF and just test the predictive accuracy of it again.
# So this is fast by comparison, we just have to rerun every row forward through the forest for each shuffled column.
#
# Q: If you want to look for interaction effects, would you do two of them and random shuffle and then three of them [1:21:12]?
# If we want to find which pairs of variables are most important, we could do exactly the same thing each pair in turn. In practice, there are better ways to do that because that is computationally expensive.

# %% [markdown]
# # Calibration of Validation set
# Normally we should not use the test set for anything other than at the end of the competition or project to find out how we did.
# But there is one additional thing we can use the test set for: to calibrate the validation set
# ML3 [46:02].
#
# ![image.png](attachment:image.png)
#
# Here they built 4 different models and submitted each to Kaggle to find its score.
# X-axis is the Kaggle score, y-axis is the score on a particular validation set $V$.
# If $V$ is good, then the relationship between the leaderboards score (i.e. the test set score) should lie in a straight line.
# Ideally, it will lie on the $y = x$ line.
# In this case, $V$ looks like it is going to predict the score well.
# This is good, since we can now try many different things (models, feature engineering, weighting, tweaks, hyper parameters), and see how they do on the validation set, without submitting to Kaggle.
# So we get more iterations and feedback.
# This is true for every ML project.
# If the validation set is not showing nice fit line, you need think carefully [48:02].
# How is the test set constructed and how is the validation set different?
# We may need to draw lots of charts to find out.

# %% [markdown]
# # position of random forests
# RFs belong to the class of techniques of *decision tree ensembles*
# along with gradient boosting machines (GBM), and
# some variants like extremely randomized trees.
# They have the benefit that they're highly interpretive, scalable, flexible.
# RFs work well for most kinds of data but they don't extrapolate to data
# that's outside the range that they have seen.
#
# There are many ML tools, but courses and books
# don't attempt to curate and define for which
# kinds of problems to use which kinds of algorithms.
#
# We don't see why to ever use in Support Vector Machine (SVM) today.
# The other key type is Gradient Boosting Machines (GBM).
# Leo Breiman created RFs late in his life and passed away.
# Little has been written about RFs in the academic literature.
# RFs are hard to grasp at a theoretical level.
# Most work is coming from industry, GBM, x3boost, Ranger4r, scikit-learn.
#
# RFs have a nice benefit over GBMs, they're kind of harder to screw up,
# and easier to scale.

# %% [markdown]
# # size of validation set
#
# First we need to answer the question of how accurate do we need the predictions to be.
# If it is a range 65-75 % or it is more specific, eg 69.95%
# For example, looking at dogs versus cats images with models
# that had 99.4% accuracy,
# and the validation set was of size 2000.
# So the number of incorrect is about 12 wrong (6 cats wrong).
# Another model had accuracy of 99.2%.
# It got 2 more cats wrong, not a big deal.
# But, if this was about finding fraud, then the difference
# is 25% of the cost of fraud, which can be huge.
# Here, and in many other cases, we need to consider how much
# the error was reduced.
# In the above case, 25% accepting fraudulent customers is a big difference.
# In a particular validation set it may be 6 vs 8 cats.
# But a .2% difference can be important in the real world.
# <br>
# Rule of thumb: how many observations we are looking at
# should be higher than 22, because 22 is the magic number where the t-distribution
# roughly turns into the normal distribution.
# The T distribution is the normal distribution for small data sets.
# Once we have 22 or more it kind of starts to
# behave normally in both senses of the word.
# It's more stable and we can understand it better.
#
# So when somebody says do I have enough of something I
# start out by do you have 22 observations of the thing of interest?
# If you were looking at, eg lung cancer,
# and the data set had 1000 people without lung cancer and 20 people with
# lung cancer.
# Then we doubt we're going to make much progress,
# because we haven't even got 20 of the variable we want.
# Same with a validation set.
# If we don't have 20 of the thing we want,
# it is unlikely to be useful.
# Or if the level of accuracy we need it's not plus or minus 20,
# that's the point to be careful.
# We want 22+ samples in each set, validation, test and Train set.
# If there is less than 22 of a class in any of the sets,
# then it's unstable at that point.
#
# Start practicing what we learned about the binomial (Bernoulli) distribution.
# <br>
# - The mean of the binomial distribution of n samples and probability p: $n * p$
# - standard deviation is $n*p*(1-p)$
#
# NB: "We don't have to run this 100 times, it's binomial it's going to be  $n*p*(1-p)$
#
# The standard error (stderr) is if we run trials each time getting a mean what
# is the standard deviation of the mean
# Important because this means if you train a 100 models,
# each time the validation set accuracy is the mean of a distribution.
# Thus the standard deviation of that validation set accuracy
# can be calculated with the standard error.
# $ stderr = std / sqrt(n)$
#
# An approach to figuring out is my validation set big enough is
# to train our model 5 times with exactly the same hyper parameters.
# Then look at the validation set accuracy each time
# and get a mean and a standard deviation of five numbers.
# We could use or a maximum and a minimum.
#
# To save some time, we can figure out straight away
# that like okay well I have .99 as to whether I get the cat correct or not
# Therefore the standard deviation is equal to 0.99 times 0.01.
# Then I can get the standard error of that.
# So the size of the validation set we need is however big
# it has to be, such that your insights about its accuracy
# are good enough for a particular business problem.
#
# A simple way is to pick a validation set of 1000,
# train 5 models and see how much the validation set accuracy varies.
# If they're close enough for what we need, its OK.
# Else, we should make the validation set bigger,
# or maybe consider using cross-validation instead.
#
# So it depends on what we are trying to do,
# how common our less-common class is, and how accurate the model is.
#
# Q: If we have less than 22 of the less common class...
# If we have only one sample, couldn't
# put it in the test set because that would be
# asking can I recognize something I've never seen before.
# The question of can I recognize something I've
# not seen before,  there's a class of models specifically for that
# purpose called either *one-shot learning*,
# which is you get to see something once and you have to recognize
# it again or *zero shot learning*
# which is where you have to recognize something
# you've never seen before.
#
# ## Unbalanced datasets
# In general our validation set and test set need to have
# the same mix or frequency observations that
# we're going to see in production.
# The training set should have an equal number in each class.
# If you don't just replicate the less common one until it is equal.
# A 2017? paper they tried lots of different approaches to
# training with unbalanced datasets and found consistently that
# over sampling the less common class
# until it is the same size as the more common class
# is always the right thing to do.
# If we only got 10 examples of people with cancer
# and 100 without, we could just copy those 10 so we get 90 more.
# Because of memory efficiency, SKlearn RFs
# have a class weights parameter that says each time your boot strapping
# or resampling we want to sample the less common class with a higher probability.
# In DL, make sure our minibatch is not randomly sampled
# but it's a stratified sample so the less common class is picked more often.

# %% [markdown]
# # Random Forest vs ANN
# In RF, we end up being rather data limited because every time
# we put in another decision point,
# we're halving our data, so this limitation on
# the amount of calculation that we can do.
# But on ANNs we're going to use lots of parameters
# using these tricks (regularization),
# so we're going to be able to do lots of computation,
# with little limitation.
